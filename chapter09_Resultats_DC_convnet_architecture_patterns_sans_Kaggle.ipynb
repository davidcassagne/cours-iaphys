# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Third Edition](https://www.manning.com/books/deep-learning-with-python-third-edition). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# The book's contents are available online at [deeplearningwithpython.io](https://deeplearningwithpython.io).

# %%
# Ajout DC
# La ligne suivante est inutile dans Google Colab
# !pip install keras keras-hub --upgrade -q

# %%
import os
os.environ["KERAS_BACKEND"] = "jax"

# %%
# @title
import os
from IPython.core.magic import register_cell_magic

@register_cell_magic
def backend(line, cell):
    current, required = os.environ.get("KERAS_BACKEND", ""), line.split()[-1]
    if current == required:
        get_ipython().run_cell(cell)
    else:
        print(
            f"This cell requires the {required} backend. To run it, change KERAS_BACKEND to "
            f"\"{required}\" at the top of the notebook, restart the runtime, and rerun the notebook."
        )

# %% [markdown]
# ## ConvNet architecture patterns

# %% [markdown]
# ### Modularity, hierarchy, and reuse

# %% [markdown]
# ### Residual connections

# %%
import keras
from keras import layers

inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
residual = layers.Conv2D(64, 1)(residual)
x = layers.add([x, residual])

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Conv2D(32, 3, activation="relu")(inputs)
residual = x
x = layers.Conv2D(64, 3, activation="relu", padding="same")(x)
x = layers.MaxPooling2D(2, padding="same")(x)
residual = layers.Conv2D(64, 1, strides=2)(residual)
x = layers.add([x, residual])

# %%
inputs = keras.Input(shape=(32, 32, 3))
x = layers.Rescaling(1.0 / 255)(inputs)

def residual_block(x, filters, pooling=False):
    residual = x
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    x = layers.Conv2D(filters, 3, activation="relu", padding="same")(x)
    if pooling:
        x = layers.MaxPooling2D(2, padding="same")(x)
        residual = layers.Conv2D(filters, 1, strides=2)(residual)
    elif filters != residual.shape[-1]:
        residual = layers.Conv2D(filters, 1)(residual)
    x = layers.add([x, residual])
    return x

x = residual_block(x, filters=32, pooling=True)
x = residual_block(x, filters=64, pooling=True)
x = residual_block(x, filters=128, pooling=False)

x = layers.GlobalAveragePooling2D()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %% [markdown]
# ### Batch normalization

# %% [markdown]
# ### Depthwise separable convolutions

# %% [markdown]
# ### Putting it together: A mini Xception-like model

# %% [markdown]
# **DC cellules non traités dans la version sans Kaggle**

# %% [markdown]
# import kagglehub
#
# kagglehub.login()

# %% [markdown]
# import zipfile
#
# download_path = kagglehub.competition_download("dogs-vs-cats")
#
# with zipfile.ZipFile(download_path + "/train.zip", "r") as zip_ref:
#     zip_ref.extractall(".")

# %% [markdown]
# import os, shutil, pathlib
# from keras.utils import image_dataset_from_directory
#
# original_dir = pathlib.Path("train")
# new_base_dir = pathlib.Path("dogs_vs_cats_small")
#
# def make_subset(subset_name, start_index, end_index):
#     for category in ("cat", "dog"):
#         dir = new_base_dir / subset_name / category
#         os.makedirs(dir)
#         fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
#         for fname in fnames:
#             shutil.copyfile(src=original_dir / fname, dst=dir / fname)
#
# make_subset("train", start_index=0, end_index=1000)
# make_subset("validation", start_index=1000, end_index=1500)
# make_subset("test", start_index=1500, end_index=2500)

# %% [markdown]
# **Ajout DC**
#
# Télécharger le fichier cats_vs_dogs_small.zip disponible dans Moodle.
#
# Puis exécuter la cellule suivante.

# %%
import zipfile

with zipfile.ZipFile("cats_vs_dogs_small.zip", "r") as zip_ref:
    zip_ref.extractall(".")

# %%
import pathlib
new_base_dir = pathlib.Path("cats_vs_dogs_small")

# %%
from keras.utils import image_dataset_from_directory

batch_size = 64
image_size = (180, 180)
train_dataset = image_dataset_from_directory(
    new_base_dir / "train",
    image_size=image_size,
    batch_size=batch_size,
)
validation_dataset = image_dataset_from_directory(
    new_base_dir / "validation",
    image_size=image_size,
    batch_size=batch_size,
)
test_dataset = image_dataset_from_directory(
    new_base_dir / "test",
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %%
import tensorflow as tf
from keras import layers

data_augmentation_layers = [
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.2),
]

def data_augmentation(images, targets):
    for layer in data_augmentation_layers:
        images = layer(images)
    return images, targets

augmented_train_dataset = train_dataset.map(
    data_augmentation, num_parallel_calls=8
)
augmented_train_dataset = augmented_train_dataset.prefetch(tf.data.AUTOTUNE)

# %%
import keras

inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1.0 / 255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)

for size in [32, 64, 128, 256, 512]:
    residual = x

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.SeparableConv2D(size, 3, padding="same", use_bias=False)(x)

    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    residual = layers.Conv2D(
        size, 1, strides=2, padding="same", use_bias=False
    )(residual)
    x = layers.add([x, residual])

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

# %%
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=["accuracy"],
)
history = model.fit(
    augmented_train_dataset,
    epochs=100,
    validation_data=validation_dataset,
)
# Out:
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 105s 2s/step - accuracy: 0.5071 - loss: 0.7249 - val_accuracy: 0.5000 - val_loss: 0.6990
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 15s 64ms/step - accuracy: 0.6060 - loss: 0.6628 - val_accuracy: 0.4990 - val_loss: 0.6946
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.6046 - loss: 0.6395 - val_accuracy: 0.5000 - val_loss: 0.7009
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6768 - loss: 0.6153 - val_accuracy: 0.5000 - val_loss: 0.6942
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.6614 - loss: 0.6001 - val_accuracy: 0.5000 - val_loss: 0.7037
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.6979 - loss: 0.5879 - val_accuracy: 0.5010 - val_loss: 0.6933
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.7122 - loss: 0.5779 - val_accuracy: 0.5000 - val_loss: 0.7346
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7130 - loss: 0.5704 - val_accuracy: 0.5000 - val_loss: 0.7538
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.7378 - loss: 0.5370 - val_accuracy: 0.5000 - val_loss: 0.7805
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - accuracy: 0.7216 - loss: 0.5586 - val_accuracy: 0.5000 - val_loss: 0.8010
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7774 - loss: 0.4795 - val_accuracy: 0.5110 - val_loss: 0.7292
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8039 - loss: 0.4446 - val_accuracy: 0.5060 - val_loss: 0.8197
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.7720 - loss: 0.4766 - val_accuracy: 0.5530 - val_loss: 0.7714
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.7915 - loss: 0.4617 - val_accuracy: 0.5140 - val_loss: 1.2008
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.7989 - loss: 0.4351 - val_accuracy: 0.5990 - val_loss: 0.8210
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8235 - loss: 0.4009 - val_accuracy: 0.5750 - val_loss: 0.9443
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8219 - loss: 0.3961 - val_accuracy: 0.5620 - val_loss: 1.4240
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8180 - loss: 0.4080 - val_accuracy: 0.6350 - val_loss: 0.7565
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8184 - loss: 0.3979 - val_accuracy: 0.5920 - val_loss: 1.0978
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8293 - loss: 0.3829 - val_accuracy: 0.7790 - val_loss: 0.4645
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8560 - loss: 0.3574 - val_accuracy: 0.7630 - val_loss: 0.4811
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8400 - loss: 0.3738 - val_accuracy: 0.6730 - val_loss: 0.7550
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8473 - loss: 0.3531 - val_accuracy: 0.7630 - val_loss: 0.4933
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8508 - loss: 0.3452 - val_accuracy: 0.7750 - val_loss: 0.4880
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8650 - loss: 0.3223 - val_accuracy: 0.8060 - val_loss: 0.5421
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.8736 - loss: 0.2986 - val_accuracy: 0.7260 - val_loss: 0.6112
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8604 - loss: 0.3096 - val_accuracy: 0.7220 - val_loss: 0.8248
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8631 - loss: 0.3137 - val_accuracy: 0.7940 - val_loss: 0.4497
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8873 - loss: 0.2885 - val_accuracy: 0.8090 - val_loss: 0.4619
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8565 - loss: 0.3264 - val_accuracy: 0.7920 - val_loss: 0.4537
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8962 - loss: 0.2592 - val_accuracy: 0.7050 - val_loss: 0.9688
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.8771 - loss: 0.2725 - val_accuracy: 0.7920 - val_loss: 0.4403
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.8768 - loss: 0.2919 - val_accuracy: 0.7750 - val_loss: 0.4708
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.8949 - loss: 0.2596 - val_accuracy: 0.7820 - val_loss: 0.5298
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.8897 - loss: 0.2605 - val_accuracy: 0.8290 - val_loss: 0.4053
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.8837 - loss: 0.2612 - val_accuracy: 0.8000 - val_loss: 0.4483
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.8887 - loss: 0.2546 - val_accuracy: 0.8050 - val_loss: 0.4246
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9007 - loss: 0.2376 - val_accuracy: 0.7750 - val_loss: 0.4836
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9137 - loss: 0.2281 - val_accuracy: 0.7690 - val_loss: 0.8612
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9064 - loss: 0.2287 - val_accuracy: 0.8170 - val_loss: 0.4659
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9059 - loss: 0.2122 - val_accuracy: 0.7780 - val_loss: 0.7281
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9071 - loss: 0.2214 - val_accuracy: 0.8280 - val_loss: 0.4862
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9126 - loss: 0.2145 - val_accuracy: 0.8260 - val_loss: 0.4527
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9141 - loss: 0.2089 - val_accuracy: 0.8020 - val_loss: 0.6061
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9271 - loss: 0.1966 - val_accuracy: 0.7200 - val_loss: 0.9279
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9143 - loss: 0.1968 - val_accuracy: 0.8360 - val_loss: 0.4200
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9187 - loss: 0.1932 - val_accuracy: 0.8060 - val_loss: 0.5436
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9113 - loss: 0.2047 - val_accuracy: 0.8520 - val_loss: 0.3554
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9259 - loss: 0.1832 - val_accuracy: 0.7390 - val_loss: 0.7396
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9302 - loss: 0.1783 - val_accuracy: 0.7880 - val_loss: 0.5192
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9087 - loss: 0.2188 - val_accuracy: 0.7370 - val_loss: 0.9926
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9225 - loss: 0.1968 - val_accuracy: 0.8530 - val_loss: 0.3661
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9426 - loss: 0.1436 - val_accuracy: 0.8320 - val_loss: 0.5117
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9404 - loss: 0.1561 - val_accuracy: 0.8360 - val_loss: 0.4708
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9487 - loss: 0.1384 - val_accuracy: 0.8380 - val_loss: 0.5529
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - accuracy: 0.9298 - loss: 0.1798 - val_accuracy: 0.7880 - val_loss: 0.6641
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9255 - loss: 0.1752 - val_accuracy: 0.8510 - val_loss: 0.3708
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9311 - loss: 0.1704 - val_accuracy: 0.8630 - val_loss: 0.3948
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9418 - loss: 0.1312 - val_accuracy: 0.8340 - val_loss: 0.5546
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9448 - loss: 0.1386 - val_accuracy: 0.8550 - val_loss: 0.3710
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9544 - loss: 0.1348 - val_accuracy: 0.8470 - val_loss: 0.4266
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9326 - loss: 0.1682 - val_accuracy: 0.8520 - val_loss: 0.4206
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9427 - loss: 0.1356 - val_accuracy: 0.8640 - val_loss: 0.3458
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9451 - loss: 0.1238 - val_accuracy: 0.8600 - val_loss: 0.3116
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9371 - loss: 0.1636 - val_accuracy: 0.8320 - val_loss: 0.5240
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9375 - loss: 0.1512 - val_accuracy: 0.7500 - val_loss: 1.0366
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9369 - loss: 0.1530 - val_accuracy: 0.8530 - val_loss: 0.4273
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9396 - loss: 0.1271 - val_accuracy: 0.8630 - val_loss: 0.3998
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9427 - loss: 0.1441 - val_accuracy: 0.8430 - val_loss: 0.4615
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9439 - loss: 0.1431 - val_accuracy: 0.6810 - val_loss: 1.7240
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9421 - loss: 0.1364 - val_accuracy: 0.8670 - val_loss: 0.4331
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9628 - loss: 0.1060 - val_accuracy: 0.7990 - val_loss: 0.5675
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9505 - loss: 0.1253 - val_accuracy: 0.8360 - val_loss: 0.5285
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9578 - loss: 0.1106 - val_accuracy: 0.7760 - val_loss: 0.8857
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - accuracy: 0.9271 - loss: 0.1779 - val_accuracy: 0.8730 - val_loss: 0.4074
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9527 - loss: 0.1234 - val_accuracy: 0.8310 - val_loss: 0.5814
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9646 - loss: 0.0874 - val_accuracy: 0.8410 - val_loss: 0.4110
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9731 - loss: 0.0777 - val_accuracy: 0.8300 - val_loss: 0.5885
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9535 - loss: 0.1155 - val_accuracy: 0.7860 - val_loss: 0.8978
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9454 - loss: 0.1347 - val_accuracy: 0.8840 - val_loss: 0.3289
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9524 - loss: 0.1155 - val_accuracy: 0.8620 - val_loss: 0.3902
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - accuracy: 0.9719 - loss: 0.0833 - val_accuracy: 0.8190 - val_loss: 0.6588
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9521 - loss: 0.1086 - val_accuracy: 0.8250 - val_loss: 0.5555
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9495 - loss: 0.1301 - val_accuracy: 0.8600 - val_loss: 0.3971
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9702 - loss: 0.0774 - val_accuracy: 0.8630 - val_loss: 0.4861
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 70ms/step - accuracy: 0.9673 - loss: 0.0917 - val_accuracy: 0.8720 - val_loss: 0.3780
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9533 - loss: 0.1227 - val_accuracy: 0.8770 - val_loss: 0.3979
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9548 - loss: 0.1057 - val_accuracy: 0.8750 - val_loss: 0.4689
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9507 - loss: 0.1249 - val_accuracy: 0.8050 - val_loss: 0.5769
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9617 - loss: 0.1004 - val_accuracy: 0.7370 - val_loss: 1.2656
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9617 - loss: 0.0929 - val_accuracy: 0.7560 - val_loss: 1.0916
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9573 - loss: 0.0958 - val_accuracy: 0.8740 - val_loss: 0.3813
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9775 - loss: 0.0801 - val_accuracy: 0.8490 - val_loss: 0.5873
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - accuracy: 0.9756 - loss: 0.0717 - val_accuracy: 0.8600 - val_loss: 0.5598
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9700 - loss: 0.0929 - val_accuracy: 0.8680 - val_loss: 0.4419
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9596 - loss: 0.1135 - val_accuracy: 0.8570 - val_loss: 0.5059
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.9736 - loss: 0.0771 - val_accuracy: 0.8540 - val_loss: 0.4293
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9594 - loss: 0.1045 - val_accuracy: 0.8390 - val_loss: 0.5218
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9631 - loss: 0.0952 - val_accuracy: 0.8280 - val_loss: 0.4373
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9768 - loss: 0.0664 - val_accuracy: 0.8760 - val_loss: 0.3784

# %% [markdown]
# ### Beyond convolution: Vision Transformers
